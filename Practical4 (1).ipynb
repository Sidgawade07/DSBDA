# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\Facebook\Facebook_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0           0            139441   Photo         2          12             4
# 1           1            139441  Status         2          12             3
# 2           2            139441   Photo         3          12             3
# 3           3            139441   Photo         2          12             2
# 4           4            139441   Photo         2          12             2
#
#    Post Hour  Paid  Lifetime Post Total Reach  \
# 0          3   0.0                       2752
# 1         10   0.0                      10460
# 2          3   0.0                       2413
# 3         10   1.0                      50128
# 4          3   0.0                       7244
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Page total likes', 'Type', 'Category', 'Post Month',
#        'Post Weekday', 'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Unnamed: 0                                                           500 non-null    int64
#  1   Page total likes                                                     500 non-null    int64
#  2   Type                                                                 500 non-null    object
#  3   Category                                                             500 non-null    int64
#  4   Post Month                                                           500 non-null    int64
#  5   Post Weekday                                                         500 non-null    int64
#  6   Post Hour                                                            500 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                             0
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# ...

# %%
df=df.dropna(how='any',axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 495 entries, 0 to 498
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Unnamed: 0                                                           495 non-null    int64
#  1   Page total likes                                                     495 non-null    int64
#  2   Type                                                                 495 non-null    object
#  3   Category                                                             495 non-null    int64
#  4   Post Month                                                           495 non-null    int64
#  5   Post Weekday                                                         495 non-null    int64
#  6   Post Hour                                                            495 non-null    int64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid', 'Lifetime Post Total Reach', 'Lifetime Post Total Impressions', 'Lifetime Engaged Users', 'Lifetime Post Consumers', 'Lifetime Post Consumptions', 'Lifetime Post Impressions by people who have liked your Page', 'Lifetime Post reach by people who like your Page', 'Lifetime People who have liked your Page and engaged with your post', 'comment', 'like', 'share', 'Total Interactions']

# %%
df1=df[['Category','Type','Total Interactions']]
df2=df[['Category','Post Month','Post Hour']]
print(df1)
print(df2)
# Out:
#      Category    Type  Total Interactions
# 0           2   Photo                 100
# 1           2  Status                 164
# 2           3   Photo                  80
# 3           2   Photo                1777
# 4           2   Photo                 393
# ..        ...     ...                 ...
# 494         3   Photo                 176
# 495         3   Photo                  84
# 496         2   Photo                  75
# 497         1   Photo                 115
# 498         3   Photo                 136
#
# [495 rows x 3 columns]
#      Category  Post Month  Post Hour
# 0           2          12          3
# 1           2          12         10
# 2           3          12          3
# 3           2          12         10
# 4           2          12          3
# ..        ...         ...        ...
# 494         3           1         10
# 495         3           1          2
# 496         2           1          8
# 497         1           1          2
# ...

# %%
merged_df=pd.merge(df1,df2,on='Category')
print(merged_df)
# Out:
#        Category   Type  Total Interactions  Post Month  Post Hour
# 0             2  Photo                 100          12          3
# 1             2  Photo                 100          12         10
# 2             2  Photo                 100          12         10
# 3             2  Photo                 100          12          3
# 4             2  Photo                 100          12          9
# ...         ...    ...                 ...         ...        ...
# 85182         3  Photo                 136           1          3
# 85183         3  Photo                 136           1          2
# 85184         3  Photo                 136           1         10
# 85185         3  Photo                 136           1          2
# 85186         3  Photo                 136           1         11
#
# [85187 rows x 5 columns]

# %%
df_sorted=df.sort_values(by=['Category','Post Month'])
print(df_sorted.head())
# Out:
#      Unnamed: 0  Page total likes   Type  Category  Post Month  Post Weekday  \
# 476         476             86909  Photo         1           1             6
# 477         477             86909   Link         1           1             6
# 481         481             86491   Link         1           1             4
# 485         485             86491   Link         1           1             2
# 492         492             85979   Link         1           1             5
#
#      Post Hour  Paid  Lifetime Post Total Reach  \
# 476         10   1.0                      37088
# 477          4   0.0                      39600
# 481          4   1.0                       4938
# 485          2   0.0                       5168
# 492         11   0.0                      45920
#
#      Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 476                            10966                    2728
# 477                             7927                     572
# ...

# %%
df_transpose=df.head().T
print(df_transpose)
# Out:
#                                                          0       1       2  \
# Unnamed: 0                                               0       1       2
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# ...

# %%
print(df.shape)
# Out:
# (495, 20)

# %%
df_melted=pd.melt(df,id_vars=['Category'],value_vars=['like','share','comment'])
print(df_melted)
# Out:
#       Category variable   value
# 0            2     like    79.0
# 1            2     like   130.0
# 2            3     like    66.0
# 3            2     like  1572.0
# 4            2     like   325.0
# ...        ...      ...     ...
# 1480         3  comment    10.0
# 1481         3  comment     5.0
# 1482         2  comment     0.0
# 1483         1  comment     4.0
# 1484         3  comment     7.0
#
# [1485 rows x 3 columns]

# %%
df_pivot=df.pivot_table(values='Total Interactions',index='Category',columns='Type')
print(df_pivot)
# Out:
# Type       Link       Photo      Status       Video
# Category
# 1         91.25  151.928177  167.666667  295.857143
# 2         49.00  284.877778  224.578947         NaN
# 3         85.00  259.860000  182.500000         NaN
